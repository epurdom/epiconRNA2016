# %% [markdown]
# # Visualizing EPICON 2016 data
#
# Here is a small Jupyter notebook that can be used to visualize specific genes.
#
# To use, fill in the user and password to access the data (between the quotes.).
# You can modify the sample_type ("leaf" or "root") and the gene_name to whatever gene name you wish.
#
# You can then execute the cells by going through the menu "Cell", and clicking on "Run all".

# %%
user = "username"
password = "password"
sample_type = "leaf"
gene_name = "Sobic.003G356000"

# %%
# Fetches the data.
# This cell only needs to be executed once per session. The data
# will not be re-download if this cell is re-executed.
from utils_data import fetch_data
fetch_data(user=user, password=password)
# Out:
# Fetching data file: https://www.stat.berkeley.edu/~epicon/publications/rnaseq/data/RNASeq/leaf_log.tsv
# File data/RNASeq/leaf_log.tsv already exists. Skipping…
# Fetching data file: https://www.stat.berkeley.edu/~epicon/publications/rnaseq/data/RNASeq/leaf_meta.tsv
# File data/RNASeq/leaf_meta.tsv already exists. Skipping…
# Fetching data file: https://www.stat.berkeley.edu/~epicon/publications/rnaseq/data/RNASeq/root_log.tsv
# File data/RNASeq/root_log.tsv already exists. Skipping…
# Fetching data file: https://www.stat.berkeley.edu/~epicon/publications/rnaseq/data/RNASeq/root_meta.tsv
# File data/RNASeq/root_meta.tsv already exists. Skipping…

# %%
from utils_vis import plot_gene

# %%
plot_gene(gene_name, sample_type=sample_type)
